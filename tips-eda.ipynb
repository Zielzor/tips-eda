# %%
import pandas as pd 
import seaborn as sns

# %%
tips = sns.load_dataset("tips")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.3 KB

# %%
tips.corr()
# Out:
#             total_bill       tip      size  total_pct
# total_bill    1.000000  0.675734  0.598315  -0.338624
# tip           0.675734  1.000000  0.489299   0.342370
# size          0.598315  0.489299  1.000000  -0.142860
# total_pct    -0.338624  0.342370 -0.142860   1.000000

# %%
tips.day.unique()
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Sun', 'Sat', 'Thur', 'Fri']

# %%
tips.day.value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
tips.time.unique()
# Out:
# ['Dinner', 'Lunch']
# Categories (2, object): ['Dinner', 'Lunch']

# %%
tips.time.value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
tips.time.value_counts(normalize=True)
# Out:
# Dinner    0.721311
# Lunch     0.278689
# Name: time, dtype: float64

# %%
tips.day.value_counts(normalize=True)
# Out:
# Sat     0.356557
# Sun     0.311475
# Thur    0.254098
# Fri     0.077869
# Name: day, dtype: float64

# %%
tips.groupby("time")["tip"].mean()
# Out:
# time
# Lunch     2.728088
# Dinner    3.102670
# Name: tip, dtype: float64

# %%
tips.groupby(["time","sex"])["tip"].mean().unstack()
# Out:
# sex         Male    Female
# time
# Lunch   2.882121  2.582857
# Dinner  3.144839  3.002115

# %%
tips.groupby(["time","sex"])["tip"].mean()
# Out:
# time    sex
# Lunch   Male      2.882121
#         Female    2.582857
# Dinner  Male      3.144839
#         Female    3.002115
# Name: tip, dtype: float64

# %%
tips.groupby("time")["tip"].mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='time'>

# %%
tips.groupby("sex")["tip"].mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='sex'>

# %%
tips.groupby("day")["tip"].mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='day'>

# %%
tips.groupby("smoker")["tip"].mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='smoker'>

# %%
tips.groupby("size")["tip"].mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='size'>

# %%
tips["total_pct"] = tips.tip / tips.total_bill

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  total_pct
# 0       16.99  1.01  Female     No  Sun  Dinner     2   0.059447
# 1       10.34  1.66    Male     No  Sun  Dinner     3   0.160542
# 2       21.01  3.50    Male     No  Sun  Dinner     3   0.166587
# 3       23.68  3.31    Male     No  Sun  Dinner     2   0.139780
# 4       24.59  3.61  Female     No  Sun  Dinner     4   0.146808

# %%
tips.plot.scatter(x="total_bill", y="total_pct")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='total_pct'>

# %%
tips.plot.scatter(x="total_bill", y="tip")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x="total_bill", y="tip", data = tips)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x="total_bill", y="tip", data = tips, hue="sex")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x="total_bill", y="tip", data = tips, hue="time")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x="total_bill", y="tip", data = tips, hue="smoker")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x="total_bill", y="tip", data = tips, hue="day")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.relplot(
    x="total_bill",
    y="tip",
    data=tips,
    col="sex",
    hue="time"
)

# %%
sns.relplot(
    x="total_bill",
    y="tip",
    data=tips,
    col="day",
    hue="time"
)

# %%
sns.displot(
    data = tips,
    x="total_bill",
    col="time",
    kde=True

)

# %%
sns.displot(
    data = tips,
    x="total_bill",
    col="sex",
    kde=True

)

# %%
sns.displot(
    data = tips,
    x="tip",
    col="time",
    kde=True

)

# %%
sns.displot(
    data = tips,
    x="tip",
    col="size",
    kde=True

)

# %%
sns.displot(
    data = tips,
    x="size",
    col="sex",
    kde=True

)

# %%
sns.pairplot(data=tips,hue="sex")
